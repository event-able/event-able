# %% [markdown]
# # Experimenting with event data

# %%
# %matplotlib inline

# %% [markdown]
# ## Parsing events

# %%
from lxml.etree import XML
import datetime

# %%
root = XML(open('../data/events_rss.xml').read())

# %%
channel = root.getchildren()[0]

# %%
items = [n for n in channel.getchildren() if n.tag == 'item']

# %%
items[0].getchildren()
# Out:
# [<Element guid at 0x10a0bb2d8>,
#  <Element link at 0x10a0bb290>,
#  <Element category at 0x10a0bb248>,
#  <Element title at 0x10a0bb200>,
#  <Element description at 0x10a0bb1b8>,
#  <Element pubDate at 0x10a0bb170>,
#  <Element {myEvents}marketingRegion at 0x10a0bb128>,
#  <Element {myEvents}updateTimestamp at 0x10a0bb0e0>,
#  <Element {myEvents}eventDate at 0x10a0bb098>,
#  <Element {myEvents}venue at 0x10a0bb050>,
#  <Element {myEvents}councilName at 0x10a0bbc68>,
#  <Element {myEvents}multimedia at 0x10a0bbc20>,
#  <Element {myEvents}multimedia at 0x10a0bbbd8>,
#  <Element {myEvents}type at 0x10a0bb8c0>,
#  <Element {myEvents}email at 0x10a0bb9e0>,
#  <Element {myEvents}phone at 0x10a0bb998>,
#  <Element {myEvents}url at 0x10a0bba28>,
#  <Element {myEvents}organiser at 0x10a0bb908>,
#  <Element {myEvents}username at 0x10a0bba70>,
#  <Element {myEvents}toBeConfirmed at 0x10a0bb950>,
#  <Element {myEvents}freeEntry at 0x10a0bbb90>,
#  <Element {myEvents}tags at 0x10a0bbab8>,
#  <Element {myEvents}tags at 0x10a0bbb48>]

# %%
import characteristic as ch

# %%
def parse_date(d):
    return datetime.date(int(d[:4]), int(d[4:6]), int(d[6:8]))

@ch.attributes(['guid', 'link', 'category', 'title', 'description',
                'region', 'venue', 'isfree', 'date', 'tags'])
class Event(object):
    @staticmethod
    def parse(node):
        return Event(
            guid=node.find('guid').text,
            link=node.find('link').text,
            category=node.find('category').text,
            title=node.find('title').text,
            description=node.find('description').text,
            region=node.find('{myEvents}marketingRegion').text,
            venue=Venue.parse(node.find('{myEvents}venue')),
            isfree=node.find('{myEvents}freeEntry').text,
            date=parse_date(node.find('{myEvents}eventDate').text),
            tags=[t.text for t in node.findall('{myEvents}tags')],
        )
    
    def is_historical(self):
        return self.date < datetime.date.today()
    
VENUE_FIELDS = ['address', 'area', 'suburb', 'city', 'state', 'postcode', 'country']

@ch.attributes(VENUE_FIELDS)
class Venue(object):
    @staticmethod
    def parse(n):
        return Venue(**{k: n.find(k).text
                        for k in VENUE_FIELDS})

# %%
events = map(Event.parse, items)

# %% [markdown]
# ## Event dates

# %%
def events_today(all_events):
    today = datetime.date.today()
    return [e for e in events
            if e.date == today]
    
for e in events_today(events):
    print(e.category, e.title, e.tags)
# Out:
# ('LEISURE', 'Gold Fossickers Cup', ['SPORTS'])
# ('LEISURE', 'Cooking class at Olivigna', ['FOODWINE'])
# ('LEISURE', 'Frock Up Melbourne', ['SHOPPING', 'FASHION', 'ARTCULTURE'])
# ('LEISURE', 'Growing Sprouts and Microgreens', ['LIFESTYLE', 'EDUCATION'])
# ('LEISURE', 'Delicious Raw Food Workshop', ['LIFESTYLE', 'EDUCATION'])
# ('LEISURE', 'Truffle Melbourne', ['FOODWINE'])
# ('LEISURE', 'Only Dyson', ['ARTCULTURE'])
# ('LEISURE', 'ONEWorld Summit', ['COMMUNITY'])
# ('LEISURE', 'Prima Independente Concerto', ['LIVEMUSIC', 'CLASSICALC'])
# ('LEISURE', 'NAIDOC Week at the State Library', ['COMMUNITY', 'INDIGENOUS'])
# ('LEISURE', 'Winter Wakeup', ['LIVEMUSIC', 'HARDROCKHE'])
# ('LEISURE', 'Maximo Pujol Trio', ['LIVEMUSIC'])
# ('LEISURE', 'Royal Melbourne Alpaca Show', ['GARDENSAGR', 'AGRICULTUR'])
# ('LEISURE', u'Ella \u2013 First Lady of Song', ['LIVEMUSIC'])
# ('LEISURE', 'Puffing Billy&#39;s Bollywood Spectacular!', ['DINING', 'FOODWINE', 'MULTICULTU'])
# ('LEISURE', 'Extravaganza - Eat Drink Discover', ['FOODWINE', 'DINING'])

# %%
from collections import Counter

# %% [markdown]
# ### Are they all leisure?

# %%
Counter(e.category for e in events)
# Out:
# Counter({'LEISURE': 1484, 'BUSINESS': 18})

# %% [markdown]
# ### What tags are used?

# %%
tags = Counter()
for e in events:
    for t in e.tags:
        tags[t] += 1

tags.most_common(20)
# Out:
# [('ARTCULTURE', 333),
#  ('COMMUNITY', 297),
#  ('FAMILY', 264),
#  ('LIVEMUSIC', 243),
#  ('LIFESTYLE', 243),
#  ('STAGESHOWS', 228),
#  ('SPORTS', 203),
#  ('FOODWINE', 177),
#  ('EDUCATION', 135),
#  ('MARKETS', 134),
#  ('SCHOOLHOLS', 75),
#  ('DINING', 73),
#  ('PRODUCEM', 71),
#  ('MAKERSM', 70),
#  ('CLASSICALC', 67),
#  ('VINTAGEM', 62),
#  ('GARDENSAGR', 58),
#  ('THEATRE', 58),
#  ('FETEFAIR', 52),
#  ('MULTICULTU', 47)]

# %%
import networkx as nx

# %%
from itertools import combinations
weights = Counter()
for e in events:
    for t1, t2 in combinations(sorted(e.tags), 2):
        weights[t1, t2] += 1

g = nx.Graph()
for (t1, t2), weight in weights.iteritems():
    g.add_node(t1)
    g.add_node(t2)
    g.add_edge(t1, t2, weight=weight)

# %%
nx.draw_networkx(g)

# %%
nx.write_gml(g, 'tags.gml')

# %% [markdown]
# ### How many are historical?

# %%
Counter(e.is_historical() for e in events)
# Out:
# Counter({False: 1037, True: 465})

# %% [markdown]
# About 1/3 of them are historical.
